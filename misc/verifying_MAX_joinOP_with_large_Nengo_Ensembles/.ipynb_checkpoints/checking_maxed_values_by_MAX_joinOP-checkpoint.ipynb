# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#maxed_values = np.load("Maxed_Values_NC_4_R_32_C_32.npy")
maxed_values = np.load("Maxed_Values_NC_8_R_26_C_26.npy")
maxed_values.shape
# Out:
# (100, 1352)

# %%
np.random.seed(0)
#inp_mat = np.random.rand(4, 32, 32)
inp_mat = np.random.rand(8, 26, 26)

# %%
plt.plot(maxed_values[:, 7]) # Corresponds to input: 0, 0:2, 14:16 in 4 x 32 x 32.

# %%
print(inp_mat[0, 0:2, 0:2].flatten().tolist())
print(inp_mat[0, 0:2, 14:16].flatten().tolist()) # => 7 index in maxed_values.
print(inp_mat[4, 0:2, 14:16].flatten().tolist()) # => 683 index for Maxed_Values_NC_8_R_26_C_26.npy.
# Out:
# [0.5488135039273248, 0.7151893663724195, 0.1433532874090464, 0.9446689170495839]
# [0.07103605819788694, 0.08712929970154071, 0.359507900573786, 0.43703195379934145]
# [0.23260187745708427, 0.4892254993109375, 0.2063730118576239, 0.16090979579308917]

# %% [markdown]
# # ###################################################################

# %%
inp_mat[0, 1:2, 1:2]
# Out:
# array([[0.94466892]])

# %%
plt.plot(maxed_values[:, 683])

# %%
print(inp_mat[0, 0:2, 0:2].flatten().tolist())
print(inp_mat[0, 0:2, 14:16].flatten().tolist())
# Out:
# [0.5488135039273248, 0.7151893663724195, 0.45615033221654855, 0.5684339488686485]
# [0.07103605819788694, 0.08712929970154071, 0.2103825610738409, 0.1289262976548533]
